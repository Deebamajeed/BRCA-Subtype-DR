# %%
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

barWidth = 0.3



miRNA=[0.88,0.91,0.975,1.004]
mRNA=[0.9,0.93,0.97,0.97]
Methy=[0.86,0.84,0.97,1.078]
Clinical=[0.54,0.52,0.75,1.39]
Protein=[0.4,0.488,0.68,1.41]
Integ_Omics=[0.96,0.94,0.99,0.96]


# The x position of bars
r1 = [1,5,9,13]
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

rs=r1+r2+r3+r4+r5+r6

bars=miRNA+mRNA+Methy+Clinical+Protein+Integ_Omics
# Create the bars
plt.bar(r1, miRNA, width = barWidth, color = 'navy', edgecolor = 'black', capsize=7, label='miRNA')
plt.bar(r2, mRNA, width = barWidth, color = 'orange', edgecolor = 'black', capsize=7, label='mRNA')
plt.bar(r3,Protein, width = barWidth, color = 'olive', edgecolor = 'black', capsize=7, label='Protein')
plt.bar(r4, Methy, width = barWidth, color = 'magenta', edgecolor = 'black', capsize=7, label='Methylation')
plt.bar(r5, Clinical, width = barWidth, color = 'olive', edgecolor = 'black', capsize=7, label='Clinical')
plt.bar(r6, Integ_Omics, width = barWidth, color = 'limegreen', edgecolor = 'black', capsize=7, label='Proposed')



plt.xticks([r + 4*barWidth for r in r1], ['F-measure', 'Accuracy', 'AUC', 'Cost'], fontweight='light')
plt.legend(fontsize='x-small',loc='lower right')
#label=['0.909','0.93','0.837','0.87','0.586','0.625','0.622','0.756','0.85','0.819','0.779','0.739','0.549','0.537','0.51','0.669','0.865','0.893','0.778','0.798','0.902','0.927','0.825','0.855','0.907','0.932','0.83','0.859','0.896','0.92','0.785','0.835','0.908','0.934','0.825','0.854','0.901','0.928','0.828','0.855','0.886', '0.911', '0.815', '0.851']
# Text on the top of each barplot
#for i in range(len(rs)):
#    plt.text(x = rs[i]-0.09 , y = bars[i]+0.04, s = label[i], fontweight='light', size = 6,rotation=90)

plt.ylim((0,1.5))
plt.subplots_adjust(bottom= 0.2, top = 0.98)
plt.savefig('BRCA.png',dpi=720)
plt.show()

# %%
import matplotlib.pyplot as plt

barWidth = 0.3



RF=[0.88,0.91,0.975,0.87]
SVM=[0.9,0.93,0.97,0.97]
Single=[0.86,0.84,0.97,1.078]
Proposed=[0.54,0.52,0.75,1.39]
#Proposed=[0.4,0.488,0.68,1.41]



# The x position of bars
r1 = [1,5,9,13]
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]


rs=r1+r2+r3+r4

bars=RF+SVM+Single+Proposed
# Create the bars
plt.bar(r1, RF, width = barWidth, color = 'navy', edgecolor = 'black', capsize=7, label='RF')
plt.bar(r2, SVM, width = barWidth, color = 'orange', edgecolor = 'black', capsize=7, label='SVM')
plt.bar(r3,Moli, width = barWidth, color = 'olive', edgecolor = 'black', capsize=7, label='Single-mRNA')
plt.bar(r4, Malik, width = barWidth, color = 'magenta', edgecolor = 'black', capsize=7, label='Proposed')
#plt.bar(r5, Proposed, width = barWidth, color = 'olive', edgecolor = 'black', capsize=7, label='Proposed')




plt.xticks([r + 4*barWidth for r in r1], ['Accuracy', 'AUC', 'Sensitivity', 'Specificity'], fontweight='light')
plt.legend(fontsize='x-small',loc='lower right')
#label=['0.909','0.93','0.837','0.87','0.586','0.625','0.622','0.756','0.85','0.819','0.779','0.739','0.549','0.537','0.51','0.669','0.865','0.893','0.778','0.798','0.902','0.927','0.825','0.855','0.907','0.932','0.83','0.859','0.896','0.92','0.785','0.835','0.908','0.934','0.825','0.854','0.901','0.928','0.828','0.855','0.886', '0.911', '0.815', '0.851']
# Text on the top of each barplot
#for i in range(len(rs)):
#    plt.text(x = rs[i]-0.09 , y = bars[i]+0.04, s = label[i], fontweight='light', size = 6,rotation=90)

plt.ylim((0,1.5))
plt.subplots_adjust(bottom= 0.2, top = 0.98)
plt.savefig('Classification.png',dpi=720)
plt.show()

# %%
barWidth = 0.25


data= {'MOLI\n.71':0.71,'Malik et al\n.78':0.78,'SVM\n.89':0.89,'Proposed\n0.97':0.97}


# creating the dataset

courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (8, 4))

# creating the bar plot
plt.bar(courses, values, color ='Orange',
		width = 0.3)

plt.ylabel("AUC-Gemcitabine")
plt.xlabel("Comparison with similar methods")
#plt.title("State-of-the-art-methods")
plt.show()

# %%
barWidth = 0.25


data= {'MOLI\n.71':0.67,'Malik et al\n.81':0.81,'SVM\n.79':0.75,'Proposed\n0.79':0.79}


# creating the dataset

courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (8, 4))

# creating the bar plot
plt.bar(courses, values, color ='Orange',
		width = 0.3)

plt.ylabel("AUC-Docetaxel")
plt.xlabel("Comparison with similar methods")
#plt.title("State-of-the-art-methods")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.models import Model

# %% [markdown]
# Upload omics data

# %%
cp /content/run_DeepCDR* /content/DeepCDR-master/prog/

# %%
cp /content/graph.py /content/DeepCDR-master/prog/layers

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !cp /run_*.py /content/DeepCDR-master/prog/

# %%
# !pip install hickle
# Out:
# ...
#      |████████████████████████████████| 49 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 13.1 MB/s
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires h5py~=3.1.0, but you have h5py 2.10.0 which is incompatible.
# ...

# %%
# !pip install regressormetricgraphplot

# %%
 # !git clone https://github.com/ajayarunachalam/RegressorMetricGraphPlot
# Out:
# Cloning into 'RegressorMetricGraphPlot'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 67 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
import sys
sys.path.append('/content/DeepCDR-master/prog/')
sys.path.append('/content/DeepCDR-master/prog/layers')
sys.path.append('/content/DeepCDR-master/prog/regressormetricgraphplot')

# %%
# %matplotlib inline

# %%
# !python /content/DeepCDR-master/prog/run_DeepCDR_classify_21_Aug_new.py -gpu_id 0 -use_mut True -use_gexp True -use_methy True
# Out:
# /usr/local/lib/python3.7/dist-packages/hickle/hickle.py:556: UserWarning: Input argument 'file_obj' appears to be a file made with hickle v3. Using legacy load...
#   warnings.warn("Input argument 'file_obj' appears to be a file made"
# 5198 instances across 42 cell lines and 153 drugs were generated.
# 2021-08-28 07:10:53.113653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-28 07:10:53.124205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-28 07:10:53.125053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !pip install regressormetricgraphplot

# %%
# !cd RegressorMetricGraphPlot/

# %%
# !unzip /content/drive/MyDrive/BRCA_multiomics-main.zip
# Out:
# Archive:  /content/drive/MyDrive/BRCA_multiomics-main.zip
# d5a9ac38c309a69dd8e5b9dad6f0fa8818cffaff
#    creating: BRCA_multiomics-main/
#    creating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/
#    creating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/
#    creating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/.ipynb_checkpoints/
#   inflating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/.ipynb_checkpoints/Drug_response_master_analysis-checkpoint.ipynb
#   inflating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#   inflating: BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/.ipynb_checkpoints/drug-resp_analysis-Copy1-checkpoint.ipynb
# ...

# %%
#%% [code]

#%% [code]
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

df = pd.read_csv("/content/BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/drug_resp.csv", header = None)
df = df.T

# %%
concat_cluster = pd.DataFrame()

#Initialize K-means parameters
k_means = KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
    n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
    random_state=0, tol=0.0001, verbose=0 )

# %%
#run Kmeans
for i in range(0,212):
    drug = df[i].values
    drug_2d = drug.reshape(-1,1)
    k_means.fit(drug_2d)
    Z = k_means.predict(drug_2d)
    concat_cluster[i] = Z
    #print("drug:", i, "\n",Z)    
print(concat_cluster)

# %%
drug_resp_imputed= pd.read_csv('/content/BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/Drug_response_imputed.txt', sep=",")
del drug_resp_imputed['Samples']
drugs_name = pd.DataFrame(list(drug_resp_imputed))

# %%
drugs_name
# Out:
#                     0
# 0            TL_2_105
# 1             TAK_715
# 2            CP466722
# 3          BMS_345541
# 4    Genentech_Cpd_10
# ..                ...
# 207           MK_2206
# 208        PD_0332991
# 209         AZD6244_1
# 210               FMK
# 211          YK_4_279
#
# [212 rows x 1 columns]

# %%
compiled_drugs = pd.DataFrame()
drug1 = pd.DataFrame()
for i in range(0, 20):
    print("Drug", i)
    drug1['IC50'] = df.iloc[:][i] 
    drug1['Label'] = concat_cluster.iloc[:][i]
    drug1['Drug'] = [i] * 43
    drug1 = drug1.sort_values(by ='IC50')
    drug1.reset_index(drop=True,inplace=True)
    compiled_drugs = pd.concat([compiled_drugs, drug1])
    print(compiled_drugs)

# %%
df.head()

# %%
import seaborn as sns
violin_plot_drugs = plt.figure(figsize=(20,10))
ax = sns.violinplot(x="Drug", y="IC50", hue="Label", data=compiled_drugs, split=True, legend_out = True)
ax.set(xlabel='List of Drugs', ylabel='LogIC50')
# Out:
# [Text(0, 0.5, 'LogIC50'), Text(0.5, 0, 'List of Drugs')]

# %%
from sklearn import metrics
n_clusters = 2

print ("Number of clusters from 2 to 9: \n", range_n_clusters)
# Out:
# Number of clusters from 2 to 9:
#  [2, 3, 4, 5, 6, 7, 8]

# %%
for i in range(0,212):
    drug = df[i].values
    drug_2d = drug.reshape(-1,1)
    clusterer = KMeans (n_clusters=n_clusters).fit(drug_2d)
    preds = clusterer.predict(drug_2d)
    centers = clusterer.cluster_centers_

    score = metrics.silhouette_score (drug_2d, preds, metric='euclidean')
    print ("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.5663205116362263)
# For n_clusters = 2, silhouette score is 0.6070747923171464)
# For n_clusters = 2, silhouette score is 0.7260681336819703)
# For n_clusters = 2, silhouette score is 0.566230853732683)
# For n_clusters = 2, silhouette score is 0.5892141381036266)
# For n_clusters = 2, silhouette score is 0.6521198154047969)
# For n_clusters = 2, silhouette score is 0.5355927710001371)
# For n_clusters = 2, silhouette score is 0.5262041759452731)
# For n_clusters = 2, silhouette score is 0.5701065474770831)
# For n_clusters = 2, silhouette score is 0.593210603949026)
# For n_clusters = 2, silhouette score is 0.6337889196987981)
# For n_clusters = 2, silhouette score is 0.5638176419326091)
# For n_clusters = 2, silhouette score is 0.5590629687612346)
# For n_clusters = 2, silhouette score is 0.5891583578232494)
# For n_clusters = 2, silhouette score is 0.5868028519979244)
# For n_clusters = 2, silhouette score is 0.6865649025188365)
# ...

# %%
#from kmeansplots import kmeans_plot, silhouette_plot
for n in range(n_clusters):
    # Filter data points to plot each in turn.
    ys = f1[ Z==n ]
    xs = [ Z==n ]

    plt.scatter(xs, ys, color=colors[n])

plt.title("Points by cluster")

#%% [code]
drug1 = pd.DataFrame()
drug1['IC50'] = df.iloc[:][0] 
drug1['Label'] = Z
drug1 = drug1.sort_values(by ='IC50')
drug1.reset_index(drop=True,inplace=True)
#print(drug1)
print(drug1.iloc[1][:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b99546c5469e> in <module>()
#       2 for n in range(n_clusters):
#       3     # Filter data points to plot each in turn.
# ----> 4     ys = f1[ Z==n ]
#       5     xs = [ Z==n ]
#       6
#
# NameError: name 'f1' is not defined

# %%
sys.path.append('/content/BRCA_multiomics-main/BRCA_DrugResponsePredictionModel_100drugs/IC50_analysis/kmeansplots.py')

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

from matplotlib.colors import colorConverter

__license__ = 'MIT'
__author__ = 'clintval'

def darken_rgb(rgb, p):
    """
    Will darken an rgb value by p percent
    """
    assert 0 <= p <= 1, "Proportion must be [0, 1]"
    return [int(x * (1 - p)) for x in rgb]


def lighten_rgb(rgb, p):
    """
    Will lighten an rgb value by p percent
    """
    assert 0 <= p <= 1, "Proportion must be [0, 1]"
    return [int((255 - x) * p + x) for x in rgb]


def is_luminous(rgb):
    new_color = []

    for c in rgb:
        if c <= 0.03928:
            new_color.append(c / 12.92)
        else:
            new_color.append(((c + 0.055) / 1.055) ** 2.4)
    L = sum([x * y for x, y in zip([0.2126, 0.7152, 0.0722], new_color)])

    return True if L < 0.179 else False


def kmeans_plot(X, y, cluster_centers, ax=None):
    import matplotlib.patheffects as path_effects
    from sklearn.metrics.pairwise import pairwise_distances_argmin_min

    if ax is None:
        ax = plt.gca()
    print("kmeans plot)")
    cmap = cm.get_cmap("Spectral")
    colors = cmap(y.astype(float) / len(cluster_centers))
    ax.scatter(*list(zip(*X)), lw=0, c=colors, s=30)

    offset = max(list(zip(*cluster_centers))[0]) * 0.2

    for i, cluster in enumerate(cluster_centers):
        index, _ = pairwise_distances_argmin_min(cluster.reshape(1, -1), Y=X)
        cluster_color = colorConverter.to_rgb(colors[index[0]])

        if is_luminous(cluster_color) is False:
            cluster_color = darken_rgb(cluster_color, 0.35)
        print("kmeans plot)")
        label = ax.text(x=cluster[0] + offset,
                        y=cluster[1],
                        s='{:d}'.format(i + 1),
                        color=cluster_color)
        label.set_path_effects([path_effects.Stroke(lw=2, foreground='white'),
                                path_effects.Normal()])

    limit = max(*ax.get_xlim(), *ax.get_xlim())

    ax.set_xlim(0, limit)
    ax.set_ylim(0, limit)

    ax.set_xlabel("Feature space for the 1st feature")
    ax.set_ylabel("Feature space for the 2nd feature")
    return ax


def silhouette_plot(X, y, n_clusters, ax=None):
    from sklearn.metrics import silhouette_samples, silhouette_score

    if ax is None:
        ax = plt.gca()

    # Compute the silhouette scores for each sample
    silhouette_avg = silhouette_score(X, y)
    sample_silhouette_values = silhouette_samples(X, y)

    y_lower = padding = 2
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        ith_cluster_silhouette_values = sample_silhouette_values[y == i]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        
        cmap = cm.get_cmap("Spectral")
        colors = cmap(float(i) / n_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper),
                         0,
                         ith_cluster_silhouette_values,
                         facecolor=colors,
                         edgecolor=colors,
                         alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i + 1))

        # Compute the new y_lower for next plot
        y_lower = y_upper + padding

    ax.set_xlabel("The silhouette coefficient values")
    ax.set_ylabel("Cluster label")

    # The vertical line for average silhoutte score of all the values
    ax.axvline(x=silhouette_avg, c='r', alpha=0.8, lw=0.8, ls='-')
    ax.annotate('Average',
                xytext=(silhouette_avg, y_lower * 1.025),
                xy=(0, 0),
                ha='center',
                alpha=0.8,
                c='r')

    ax.set_yticks([])  # Clear the yaxis labels / ticks
    ax.set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    ax.set_ylim(0, y_upper + 1)
    ax.set_xlim(-0.075, 1.0)
    return ax

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11,4), dpi=500)
ax1 = silhouette_plot(drug_2d, preds, n_clusters=n_clusters, ax=ax1)
ax2 = kmeans_plot(drug_2d, preds, clusterer.cluster_centers_, ax=ax2)


fig.subplots_adjust(top=0.825)
fig.suptitle(("Silhouette Analysis for KMeans Clustering on Iris Data "
              "\n$clusters = {}$".format(n_clusters)),
             fontsize=14, fontweight='bold')
# Out:
# kmeans plot)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-60700b00d605> in <module>()
#       1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11,4), dpi=500)
#       2 ax1 = silhouette_plot(drug_2d, preds, n_clusters=n_clusters, ax=ax1)
# ----> 3 ax2 = kmeans_plot(drug_2d, preds, clusterer.cluster_centers_, ax=ax2)
#       4
#       5
#
# <ipython-input-60-937ef2703205> in kmeans_plot(X, y, cluster_centers, ax)
#      46     cmap = cm.get_cmap("Spectral")
#      47     colors = cmap(y.astype(float) / len(cluster_centers))
# ---> 48     ax.scatter(*list(zip(*X)), lw=0, c=colors, s=30)
#      49
#      50     offset = max(list(zip(*cluster_centers))[0]) * 0.2
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...
